# %% [markdown]
# <a href="https://colab.research.google.com/github/rayhanpratama0031/TugasPraktikum/blob/main/PRAK4/PLOTDATA_NIM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
"""
DATAPLOT1
"""

import matplotlib.pyplot as plt
import numpy as np

# Atur batas sumbu x dan y
plt.axis([0, 150, 0, 100])
plt.axis('on')  # (opsional, ini tidak diperlukan karena default-nya 'on')
plt.grid(True)  # Aktifkan grid

# --------- definisikan fungsi y1 terhadap x ---------
x = np.arange(0, 150, 1)
y1 = 10 + np.exp(0.035 * x)

# --------- plot y1 terhadap x ---------
plt.plot(x, y1, 'b', label='y1')

# Tambahkan label dan legend
plt.xlabel('x')
plt.ylabel('y1')
plt.title('Plot of y1 = 10 + exp(0.035x)')
plt.legend()

# Tampilkan plot
plt.show()

# %%
"""
DATAPLOT2
"""

import matplotlib.pyplot as plt
import numpy as np

# Atur batas sumbu x dan y
plt.axis([0, 150, 0, 100])
plt.axis('on')
plt.grid(True)

# --------- definisikan titik data ---------
x = [20, 40, 60, 80, 100, 120, 140]
y1 = [30, 50, 30, 45, 70, 43, 80]
y2 = [45, 35, 40, 60, 60, 55, 70]

# --------- plot garis dengan label ---------
plt.plot(x, y1, 'b', label='Temperature')
plt.plot(x, y2, 'r', label='Pressure')

# --------- tampilkan legenda ---------
plt.legend(loc='upper left')

# --------- tambahkan marker ---------
plt.scatter(x, y1, color='b', marker='s')        # kotak untuk y1
plt.scatter(x, y2, color='r', marker='*', s=50)   # bintang untuk y2

# Tampilkan grafik
plt.show()

# %%
"""
DATAPLOT3
"""

import matplotlib.pyplot as plt
import numpy as np

# Buat figure dan axis
fig, ax1 = plt.subplots()

# Atur batas dan grid
ax1.set_xlim([0, 140])
ax1.set_ylim([0, 100])
ax1.grid(True)

# Data
t = [20, 40, 60, 80, 100, 120, 140]  # Time
T = [30, 33, 37.5, 44, 55, 70, 86]   # Temperature
p = [1.8, 2.3, 3, 4, 5.4, 7.3, 9.6]  # Pressure

# Plot T vs t (sumbu kiri)
ax1.plot(t, T, color='r', label='Temperature')
ax1.set_xlabel('Time')
ax1.set_ylabel('Temperature', color='r')
ax1.tick_params(axis='y', labelcolor='r')
ax1.legend(loc='upper left')

# Plot P vs t (sumbu kanan)
ax2 = ax1.twinx()
ax2.plot(t, p, color='b', label='Pressure')
ax2.set_ylabel('Pressure', color='b')
ax2.tick_params(axis='y', labelcolor='b')
ax2.legend(loc='upper right')

# Judul grafik
plt.title('Test Results')

# Tampilkan grafik
plt.show()

# %%
"""
DATAPLOT4
"""

import matplotlib.pyplot as plt
import numpy as np

# Data
t = [0, 20, 40, 60, 80, 100, 120]
T = [28, 30, 35, 43, 55, 70, 85]
p = [1.8, 2.3, 3.3, 4.5, 4.7, 3.9, 6.6]

# Setup plot dengan subplots
fig, ax1 = plt.subplots()
plt.grid(True)  # Tampilkan grid

# Label sumbu X
ax1.set_xlabel('Time (hrs)')

# Plot suhu (Temperature) dengan sumbu kiri
line1 = ax1.plot(t, T, 'r', label='Temperature')  # Kurva merah
ax1.set_ylim([0, 100])  # Batas sumbu Y kiri
ax1.set_ylabel('Temperature (°K)', color='r')
ax1.tick_params(axis='y', labelcolor='r')

# Buat sumbu kanan (twin)
ax2 = ax1.twinx()

# Plot tekanan (Pressure) dengan sumbu kanan
line2 = ax2.plot(t, p, 'b', label='Pressure')  # Kurva biru
ax2.set_ylim([0, 10])  # Batas sumbu Y kanan
ax2.set_ylabel('Pressure (psi)', color='b')
ax2.tick_params(axis='y', labelcolor='b')

# Gabungkan legenda dari kedua sumbu
plt.legend(handles=line1 + line2, loc='upper left')

# Judul grafik
plt.title('Test Data')

# Tampilkan grafik
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Set axis limits and grid
plt.axis([0, 140, 0, 100])
plt.axis('on')
plt.grid(True)

# Data
t = [20, 40, 60, 80, 100, 120]               # time
T = [30, 35, 43, 55, 70, 85]                 # temperature
p = [2, 3.4, 5.3, 7.3, 9.6]                  # pressure
v = [0.6, 0.58, 0.54, 0.46, 0.35, 0.2]       # volume

# Scale pressure by 10 and volume by 100 for plotting
pp = [pi * 10 for pi in p]
vv = [vi * 100 for vi in v]

# Plot data
plt.plot(t, T, color='r', label='Temperature', marker='o')       # Temperature
plt.plot(t[:5], pp, color='b', label='Pressure', marker='s')     # Scaled pressure (same length as p)
plt.plot(t, vv, color='g', label='Volume', marker='d')           # Scaled volume

# Add legend
plt.legend(loc='upper left')

# Annotate pressure scale on right (manually)
for y in np.arange(0, 100+1, 20):
    a = y / 10
    a = str(a)
    plt.text(142, y, a, color='b')  # position text on far right

# Label axes
plt.xlabel('Time (hrs)')
plt.ylabel('Temperature °K', color='r')
plt.text(151, 65, 'Pressure (psi)', rotation=90, color='b')

# Annotate volume scale (manually)
for y in np.arange(100, -1, -20):
    a = y / 100
    a = str(a)
    plt.text(162, y, a, color='g')
    plt.text(159, y + 2, '_', color='g')

# Add minor ticks for volume
for y in np.arange(1, 99, 3):
    plt.text(157, y, '_', color='g')

# Volume label
plt.text(170, 65, 'Volume (cm³)', rotation=90, color='g')

# Title
plt.title('Compression Test Results')

# Show plot
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Contoh data (ganti dengan data asli jika perlu)
t = np.array([0, 1, 2, 3, 4, 5])
v = np.array([0, 2, 4.1, 6.1, 7.9, 10.2])

# ===== Regresi Linier =====
n = len(v)

c1 = np.sum(t) / n  # rata-rata t
c2 = np.sum(v) / n  # rata-rata v
a = np.multiply(v, t)
c3 = np.sum(a)
a = np.multiply(t, t)
c4 = np.sum(a)

A = (c3 - n * c1 * c2) / (c4 - n * c1 * c1)
B = c2 - A * c1

# Atur batas sumbu x dan y
plt.axis([0, 150, 0, 100])
plt.axis('on')  # (opsional, ini tidak diperlukan karena default-nya 'on')
plt.grid(True)  # Aktifkan grid


# ===== Plot hasil regresi =====
for tp in np.arange(t[0], t[5], 2):
    vp = A * tp + B
    vp = vp * 100  # penskalaan (bisa dihilangkan jika tidak diperlukan)
    plt.scatter(tp, vp, color='g', s=1)

# --------- definisikan fungsi y1 terhadap x ---------
x = np.arange(0, 150, 1)
y1 = 10 + np.exp(0.035 * x)

# ===== Hitung RMS error =====
sumee = 0
for i in range(len(t)):
    e = v[i] - (A * t[i] + B)
    ee = e * e
    sumee += ee
rms = np.sqrt(sumee / n)

# ===== Tambah label ke grafik =====
plt.text(60, 28, 'v=At+B', color='g')
plt.arrow(78, 30, 6, 6, head_length=3, head_width=1.5, color='g', linewidth=0.5)

# Data
t = [20, 40, 60, 80, 100, 120]               # time
T = [30, 35, 43, 55, 70, 85]                 # temperature
p = [2, 3.4, 5.3, 7.3, 9.6]                  # pressure
v = [0.6, 0.58, 0.54, 0.46, 0.35, 0.2]       # volume

# Scale pressure by 10 and volume by 100 for plotting
pp = [pi * 10 for pi in p]
vv = [vi * 100 for vi in v]

# Plot data
plt.plot(t, T, color='r', label='Temperature', marker='o')       # Temperature
plt.plot(t[:5], pp, color='b', label='Pressure', marker='s')     # Scaled pressure (same length as p)
plt.plot(t, vv, color='g', label='Volume', marker='d')           # Scaled volume

# Add legend
plt.legend(loc='upper left')

# Annotate pressure scale on right (manually)
for y in np.arange(0, 100+1, 20):
    a = y / 10
    a = str(a)
    plt.text(142, y, a, color='b')  # position text on far right

# Label axes
plt.xlabel('Time (hrs)')
plt.ylabel('Temperature °K', color='r')
plt.text(151, 65, 'Pressure (psi)', rotation=90, color='b')

# Annotate volume scale (manually)
for y in np.arange(100, -1, -20):
    a = y / 100
    a = str(a)
    plt.text(162, y, a, color='g')
    plt.text(159, y + 2, '_', color='g')

# Add minor ticks for volume
for y in np.arange(1, 99, 3):
    plt.text(157, y, '_', color='g')

# Volume label
plt.text(170, 65, 'Volume (cm³)', rotation=90, color='g')

# Titik awal dan akhir garis regresi
vp1 = A * t[0] + B
vp1 = '%7.4f' % vp1
plt.text(2, 64, vp1, color='g')

vp2 = A * t[5] + B
vp2 = '%7.4f' % vp2
plt.text(122, 25, vp2, color='g')

# Tampilkan nilai A dan B
Ap = '%7.5f' % A
plt.text(65, 18, 'A=', color='g')
plt.text(72, 18, Ap, color='g')

Bp = '%7.5f' % B
plt.text(65, 12, 'B=', color='g')
plt.text(73, 12, Bp, color='g')

# Tampilkan nilai RMS error
rms_str = '%7.3f' % rms
plt.text(95, 3, 'RMS error=', color='g')
plt.text(123, 3, rms_str, color='g')

plt.xlabel('t')
plt.ylabel('v')
plt.title('Regresi Linier v vs t')
plt.grid(True)
plt.show()
